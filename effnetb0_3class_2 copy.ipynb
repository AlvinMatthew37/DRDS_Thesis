# %%
import keras
import seaborn as sns
from keras import optimizers
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import BatchNormalization
from keras.preprocessing import image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
from keras.utils.image_utils import load_img
# import cv2
import os
import pickle
from sklearn.model_selection import train_test_split
# from pandas import DataFrame
import efficientnet.tfkeras as efn

# from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau
from keras import backend as K

import tensorflow as tf
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense, Dropout, Input
# from tensorflow.keras import layers
# from tensorflow.keras.optimizers import Adam, RMSprop, Adamax, SGD
# import efficientnet.tfkeras as efn
# from keras.models import load_model
# from tensorflow.keras import callbacks
# from tensorflow.keras.callbacks import ReduceLROnPlateau

import itertools
from sklearn import metrics
from sklearn.utils import class_weight
from sklearn.metrics import f1_score, recall_score, accuracy_score, precision_score
from sklearn.metrics import confusion_matrix, classification_report

# %%
df_train = pd.read_csv('DR_Fundus/train_edit.csv')
df_train['file_name'] = df_train["id_code"].apply(lambda x: x + ".png")
df_train['diagnosis'] = df_train['diagnosis'].astype(str)

# data_train,data_val = train_test_split(df_train,test_size = 0.25)
# print(data_train.shape,data_val.shape)
file = open('data_train_edit2', 'rb')
data_train = pickle.load(file)
file.close()

file = open('data_val_edit2', 'rb')
data_val = pickle.load(file)
file.close()

file = open('data_test_edit2', 'rb')
data_test = pickle.load(file)
file.close()

print(data_train.shape,data_val.shape, data_test.shape)
# Out:
# (2608, 4) (870, 4) (184, 4)

# %%
train_datagen = ImageDataGenerator(
                                rotation_range = 90,
                                zoom_range=0.2,
                                width_shift_range=0.2,
                                height_shift_range=0.2,
                                horizontal_flip=True,
                                vertical_flip=True)
    
train_generator = train_datagen.flow_from_dataframe(dataframe=data_train,
                                                  directory="DR_Fundus/Training_GB",
                                                  x_col="file_name",
                                                  y_col="diagnosis",
                                                  batch_size=16,
                                                  class_mode="categorical",
                                                  target_size=(224, 224),
                                                  shuffle=True,
                                                  subset='training')

test_datagen = ImageDataGenerator()

val_generator = train_datagen.flow_from_dataframe(dataframe=data_val,
                                                  directory = "DR_Fundus/Training_GB",
                                                  x_col="file_name",
                                                  y_col="diagnosis",
                                                  target_size=(224, 224),
                                                  batch_size=16,
                                                  shuffle=False,
                                                  class_mode="categorical")

test_generator = test_datagen.flow_from_dataframe(dataframe=data_test,
                                                  directory = "DR_Fundus/Training_GB",
                                                  x_col="file_name",
                                                  y_col="diagnosis",
                                                  target_size=(224, 224),
                                                  batch_size=16,
                                                  shuffle=False,
                                                  class_mode="categorical")                                            

print(len(data_train['diagnosis']))
# Out:
# Found 2608 validated image filenames belonging to 3 classes.
# Found 870 validated image filenames belonging to 3 classes.
# Found 184 validated image filenames belonging to 3 classes.
# 2608

# %%
y_train = data_train['diagnosis']
num_samples = len(y_train)
num_classes = np.unique(y_train).size
print(num_classes)

# Calculate the number of samples in each class
class_samples = np.bincount(y_train)
print(class_samples)

# Calculate the class weights using the formula
class_weights = num_samples / (num_classes * class_samples)
class_weights_dict = dict(enumerate(class_weights))
# Print the class weights
print(class_weights_dict)
# Out:
# 3
# [1274 1132  202]
# {0: 0.6823652537938252, 1: 0.767962308598351, 2: 4.303630363036303}

# %%
def focal_loss(gamma=2., alpha=.25):
	def focal_loss_fixed(y_true, y_pred):
		pt_1 = tf.where(tf.equal(y_true, 1), y_pred, tf.ones_like(y_pred))
		pt_0 = tf.where(tf.equal(y_true, 0), y_pred, tf.zeros_like(y_pred))
		return -K.mean(alpha * K.pow(1. - pt_1, gamma) * K.log(pt_1+K.epsilon())) - K.mean((1 - alpha) * K.pow(pt_0, gamma) * K.log(1. - pt_0 + K.epsilon()))
	return focal_loss_fixed

# %%
from tensorflow.keras.applications import EfficientNetB0
model = tf.keras.Sequential([
         EfficientNetB0(
            input_shape=(224,224, 3),
            weights='imagenet',
            include_top=False
        ),
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.Dense(1024, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dropout(0.25),
        tf.keras.layers.Dense(3, activation='softmax')
    ])
    
Adam = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=Adam, loss=focal_loss(),  metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional)  (None, 7, 7, 1280)       4049571
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              1311744
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 3)                 1539
#
# =================================================================
# Total params: 5,887,654
# Trainable params: 5,845,631
# Non-trainable params: 42,023
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau
def scheduler(epoch, lr):
    if (epoch < 10):
        return lr
    else:
        return lr * tf.math.exp(-0.1)

LRS = tf.keras.callbacks.LearningRateScheduler(scheduler,verbose=1)

RLROP = ReduceLROnPlateau(monitor='val_loss', mode='auto',factor=0.5, patience=2, 
                          min_lr=0.00001, cooldown=2, verbose=1)
ES = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=5, restore_best_weights=True)

# %%
import time
from PIL import Image
import scipy


start = time.time()
history = model.fit(train_generator,
                    validation_data=val_generator,
                    callbacks=[LRS,RLROP],
                    epochs=50,
                    class_weight=class_weights_dict,
                    verbose=1)
stop = time.time()
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 1/50
# 163/163 [==============================] - 44s 200ms/step - loss: 0.0453 - accuracy: 0.7753 - val_loss: 0.0311 - val_accuracy: 0.8218 - lr: 0.0010
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 2/50
# 163/163 [==============================] - 31s 191ms/step - loss: 0.0337 - accuracy: 0.8359 - val_loss: 0.0280 - val_accuracy: 0.8793 - lr: 0.0010
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 3/50
# 163/163 [==============================] - 31s 191ms/step - loss: 0.0320 - accuracy: 0.8489 - val_loss: 0.0244 - val_accuracy: 0.8805 - lr: 0.0010
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 4/50
# 163/163 [==============================] - 31s 192ms/step - loss: 0.0308 - accuracy: 0.8597 - val_loss: 0.0212 - val_accuracy: 0.8943 - lr: 0.0010
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 5/50
# 163/163 [==============================] - 31s 192ms/step - loss: 0.0299 - accuracy: 0.8658 - val_loss: 0.0232 - val_accuracy: 0.8954 - lr: 0.0010
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 6/50
# 163/163 [==============================] - ETA: 0s - loss: 0.0292 - accuracy: 0.8654
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 163/163 [==============================] - 31s 192ms/step - loss: 0.0292 - accuracy: 0.8654 - val_loss: 0.0701 - val_accuracy: 0.8184 - lr: 0.0010
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.0005000000237487257.
# Epoch 7/50
# 163/163 [==============================] - 31s 192ms/step - loss: 0.0289 - accuracy: 0.8842 - val_loss: 0.0189 - val_accuracy: 0.9011 - lr: 5.0000e-04
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.0005000000237487257.
# Epoch 8/50
# 163/163 [==============================] - 32s 195ms/step - loss: 0.0216 - accuracy: 0.8969 - val_loss: 0.0173 - val_accuracy: 0.9115 - lr: 5.0000e-04
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.0005000000237487257.
# Epoch 9/50
# 163/163 [==============================] - 36s 218ms/step - loss: 0.0210 - accuracy: 0.9061 - val_loss: 0.0163 - val_accuracy: 0.9184 - lr: 5.0000e-04
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.0005000000237487257.
# Epoch 10/50
# 163/163 [==============================] - 38s 235ms/step - loss: 0.0215 - accuracy: 0.9049 - val_loss: 0.0170 - val_accuracy: 0.9000 - lr: 5.0000e-04
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.00045241869520395994.
# Epoch 11/50
# 163/163 [==============================] - ETA: 0s - loss: 0.0203 - accuracy: 0.9041
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.00022620934760197997.
# 163/163 [==============================] - 93s 569ms/step - loss: 0.0203 - accuracy: 0.9041 - val_loss: 0.0166 - val_accuracy: 0.9126 - lr: 4.5242e-04
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.00020468267030082643.
# Epoch 12/50
# 163/163 [==============================] - 38s 233ms/step - loss: 0.0182 - accuracy: 0.9191 - val_loss: 0.0175 - val_accuracy: 0.9149 - lr: 2.0468e-04
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.000185204524314031.
# Epoch 13/50
# 163/163 [==============================] - 34s 211ms/step - loss: 0.0186 - accuracy: 0.9141 - val_loss: 0.0159 - val_accuracy: 0.9195 - lr: 1.8520e-04
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.0001675799721851945.
# Epoch 14/50
# 163/163 [==============================] - 35s 217ms/step - loss: 0.0167 - accuracy: 0.9256 - val_loss: 0.0156 - val_accuracy: 0.9264 - lr: 1.6758e-04
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.00015163261559791863.
# Epoch 15/50
# 163/163 [==============================] - 38s 231ms/step - loss: 0.0165 - accuracy: 0.9264 - val_loss: 0.0169 - val_accuracy: 0.9126 - lr: 1.5163e-04
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.00013720286369789392.
# Epoch 16/50
# 163/163 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9314
# Epoch 16: ReduceLROnPlateau reducing learning rate to 6.860143184894696e-05.
# 163/163 [==============================] - 36s 219ms/step - loss: 0.0160 - accuracy: 0.9314 - val_loss: 0.0155 - val_accuracy: 0.9276 - lr: 1.3720e-04
#
# Epoch 17: LearningRateScheduler setting learning rate to 6.20731370872818e-05.
# Epoch 17/50
# 163/163 [==============================] - 34s 209ms/step - loss: 0.0145 - accuracy: 0.9310 - val_loss: 0.0154 - val_accuracy: 0.9322 - lr: 6.2073e-05
#
# Epoch 18: LearningRateScheduler setting learning rate to 5.6166092690546066e-05.
# Epoch 18/50
# 163/163 [==============================] - 37s 225ms/step - loss: 0.0159 - accuracy: 0.9371 - val_loss: 0.0138 - val_accuracy: 0.9356 - lr: 5.6166e-05
#
# Epoch 19: LearningRateScheduler setting learning rate to 5.082117786514573e-05.
# Epoch 19/50
# 163/163 [==============================] - 37s 225ms/step - loss: 0.0142 - accuracy: 0.9337 - val_loss: 0.0154 - val_accuracy: 0.9230 - lr: 5.0821e-05
#
# Epoch 20: LearningRateScheduler setting learning rate to 4.5984899770701304e-05.
# Epoch 20/50
# 163/163 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 0.9325
# Epoch 20: ReduceLROnPlateau reducing learning rate to 2.2992449885350652e-05.
# 163/163 [==============================] - 33s 201ms/step - loss: 0.0147 - accuracy: 0.9325 - val_loss: 0.0149 - val_accuracy: 0.9264 - lr: 4.5985e-05
#
# Epoch 21: LearningRateScheduler setting learning rate to 2.080442754959222e-05.
# Epoch 21/50
# 163/163 [==============================] - 32s 193ms/step - loss: 0.0139 - accuracy: 0.9383 - val_loss: 0.0143 - val_accuracy: 0.9299 - lr: 2.0804e-05
#
# Epoch 22: LearningRateScheduler setting learning rate to 1.8824623111868277e-05.
# Epoch 22/50
# 163/163 [==============================] - 31s 191ms/step - loss: 0.0144 - accuracy: 0.9321 - val_loss: 0.0140 - val_accuracy: 0.9368 - lr: 1.8825e-05
#
# Epoch 23: LearningRateScheduler setting learning rate to 1.7033222320606e-05.
# Epoch 23/50
# 163/163 [==============================] - ETA: 0s - loss: 0.0132 - accuracy: 0.9417
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1e-05.
# 163/163 [==============================] - 31s 190ms/step - loss: 0.0132 - accuracy: 0.9417 - val_loss: 0.0155 - val_accuracy: 0.9264 - lr: 1.7033e-05
#
# Epoch 24: LearningRateScheduler setting learning rate to 9.048373613040894e-06.
# Epoch 24/50
# 163/163 [==============================] - 31s 190ms/step - loss: 0.0131 - accuracy: 0.9360 - val_loss: 0.0156 - val_accuracy: 0.9299 - lr: 9.0484e-06
#
# Epoch 25: LearningRateScheduler setting learning rate to 8.187306775653269e-06.
# Epoch 25/50
# 163/163 [==============================] - 31s 190ms/step - loss: 0.0124 - accuracy: 0.9436 - val_loss: 0.0137 - val_accuracy: 0.9345 - lr: 8.1873e-06
#
# Epoch 26: LearningRateScheduler setting learning rate to 7.408181318169227e-06.
# Epoch 26/50
# 163/163 [==============================] - 31s 191ms/step - loss: 0.0135 - accuracy: 0.9394 - val_loss: 0.0150 - val_accuracy: 0.9276 - lr: 7.4082e-06
#
# Epoch 27: LearningRateScheduler setting learning rate to 6.703199233015766e-06.
# Epoch 27/50
# 163/163 [==============================] - 31s 191ms/step - loss: 0.0136 - accuracy: 0.9329 - val_loss: 0.0137 - val_accuracy: 0.9345 - lr: 6.7032e-06
#
# Epoch 28: LearningRateScheduler setting learning rate to 6.065305115043884e-06.
# Epoch 28/50
# 163/163 [==============================] - 31s 190ms/step - loss: 0.0136 - accuracy: 0.9417 - val_loss: 0.0145 - val_accuracy: 0.9299 - lr: 6.0653e-06
#
# Epoch 29: LearningRateScheduler setting learning rate to 5.488114766194485e-06.
# Epoch 29/50
# 163/163 [==============================] - 31s 191ms/step - loss: 0.0131 - accuracy: 0.9348 - val_loss: 0.0141 - val_accuracy: 0.9322 - lr: 5.4881e-06
#
# Epoch 30: LearningRateScheduler setting learning rate to 4.9658515308692586e-06.
# Epoch 30/50
# 163/163 [==============================] - 31s 192ms/step - loss: 0.0141 - accuracy: 0.9383 - val_loss: 0.0144 - val_accuracy: 0.9322 - lr: 4.9659e-06
#
# Epoch 31: LearningRateScheduler setting learning rate to 4.4932880882697646e-06.
# Epoch 31/50
# 163/163 [==============================] - 31s 191ms/step - loss: 0.0119 - accuracy: 0.9440 - val_loss: 0.0135 - val_accuracy: 0.9368 - lr: 4.4933e-06
#
# Epoch 32: LearningRateScheduler setting learning rate to 4.065695065946784e-06.
# Epoch 32/50
# 163/163 [==============================] - 31s 192ms/step - loss: 0.0139 - accuracy: 0.9371 - val_loss: 0.0141 - val_accuracy: 0.9310 - lr: 4.0657e-06
#
# Epoch 33: LearningRateScheduler setting learning rate to 3.678792836581124e-06.
# Epoch 33/50
# 163/163 [==============================] - 31s 191ms/step - loss: 0.0124 - accuracy: 0.9425 - val_loss: 0.0154 - val_accuracy: 0.9333 - lr: 3.6788e-06
#
# Epoch 34: LearningRateScheduler setting learning rate to 3.3287092264799867e-06.
# Epoch 34/50
# 163/163 [==============================] - 31s 189ms/step - loss: 0.0145 - accuracy: 0.9394 - val_loss: 0.0140 - val_accuracy: 0.9391 - lr: 3.3287e-06
#
# Epoch 35: LearningRateScheduler setting learning rate to 3.0119404073047917e-06.
# Epoch 35/50
# 163/163 [==============================] - 31s 189ms/step - loss: 0.0131 - accuracy: 0.9367 - val_loss: 0.0155 - val_accuracy: 0.9218 - lr: 3.0119e-06
#
# Epoch 36: LearningRateScheduler setting learning rate to 2.7253163352725096e-06.
# Epoch 36/50
# 163/163 [==============================] - 31s 190ms/step - loss: 0.0127 - accuracy: 0.9433 - val_loss: 0.0148 - val_accuracy: 0.9437 - lr: 2.7253e-06
#
# Epoch 37: LearningRateScheduler setting learning rate to 2.4659680093463976e-06.
# Epoch 37/50
# 163/163 [==============================] - 31s 190ms/step - loss: 0.0140 - accuracy: 0.9394 - val_loss: 0.0146 - val_accuracy: 0.9322 - lr: 2.4660e-06
#
# Epoch 38: LearningRateScheduler setting learning rate to 2.231299959021271e-06.
# Epoch 38/50
# 163/163 [==============================] - 31s 192ms/step - loss: 0.0132 - accuracy: 0.9417 - val_loss: 0.0143 - val_accuracy: 0.9345 - lr: 2.2313e-06
#
# Epoch 39: LearningRateScheduler setting learning rate to 2.0189636416034773e-06.
# Epoch 39/50
# 163/163 [==============================] - 31s 190ms/step - loss: 0.0126 - accuracy: 0.9402 - val_loss: 0.0141 - val_accuracy: 0.9333 - lr: 2.0190e-06
#
# Epoch 40: LearningRateScheduler setting learning rate to 1.826833795348648e-06.
# Epoch 40/50
# 163/163 [==============================] - 31s 190ms/step - loss: 0.0132 - accuracy: 0.9433 - val_loss: 0.0136 - val_accuracy: 0.9437 - lr: 1.8268e-06
#
# Epoch 41: LearningRateScheduler setting learning rate to 1.6529875210835598e-06.
# Epoch 41/50
# 163/163 [==============================] - 31s 190ms/step - loss: 0.0133 - accuracy: 0.9390 - val_loss: 0.0145 - val_accuracy: 0.9287 - lr: 1.6530e-06
#
# Epoch 42: LearningRateScheduler setting learning rate to 1.4956848417568835e-06.
# Epoch 42/50
# 163/163 [==============================] - 31s 191ms/step - loss: 0.0132 - accuracy: 0.9356 - val_loss: 0.0138 - val_accuracy: 0.9333 - lr: 1.4957e-06
#
# Epoch 43: LearningRateScheduler setting learning rate to 1.3533515357266879e-06.
# Epoch 43/50
# 163/163 [==============================] - 31s 190ms/step - loss: 0.0130 - accuracy: 0.9421 - val_loss: 0.0152 - val_accuracy: 0.9345 - lr: 1.3534e-06
#
# Epoch 44: LearningRateScheduler setting learning rate to 1.2245629932294833e-06.
# Epoch 44/50
# 163/163 [==============================] - 31s 191ms/step - loss: 0.0142 - accuracy: 0.9325 - val_loss: 0.0149 - val_accuracy: 0.9207 - lr: 1.2246e-06
#
# Epoch 45: LearningRateScheduler setting learning rate to 1.1080303465860197e-06.
# Epoch 45/50
# 163/163 [==============================] - 31s 190ms/step - loss: 0.0132 - accuracy: 0.9398 - val_loss: 0.0142 - val_accuracy: 0.9402 - lr: 1.1080e-06
#
# Epoch 46: LearningRateScheduler setting learning rate to 1.0025872825281112e-06.
# Epoch 46/50
# 163/163 [==============================] - 31s 190ms/step - loss: 0.0127 - accuracy: 0.9421 - val_loss: 0.0140 - val_accuracy: 0.9414 - lr: 1.0026e-06
#
# Epoch 47: LearningRateScheduler setting learning rate to 9.07178446141188e-07.
# Epoch 47/50
# 163/163 [==============================] - 31s 191ms/step - loss: 0.0129 - accuracy: 0.9371 - val_loss: 0.0145 - val_accuracy: 0.9310 - lr: 9.0718e-07
#
# Epoch 48: LearningRateScheduler setting learning rate to 8.208489816752262e-07.
# Epoch 48/50
# 163/163 [==============================] - 31s 190ms/step - loss: 0.0131 - accuracy: 0.9402 - val_loss: 0.0142 - val_accuracy: 0.9356 - lr: 8.2085e-07
#
# Epoch 49: LearningRateScheduler setting learning rate to 7.427348123201227e-07.
# Epoch 49/50
# 163/163 [==============================] - 31s 191ms/step - loss: 0.0127 - accuracy: 0.9417 - val_loss: 0.0145 - val_accuracy: 0.9402 - lr: 7.4273e-07
#
# Epoch 50: LearningRateScheduler setting learning rate to 6.720542273797037e-07.
# Epoch 50/50
# 163/163 [==============================] - 31s 192ms/step - loss: 0.0125 - accuracy: 0.9440 - val_loss: 0.0154 - val_accuracy: 0.9345 - lr: 6.7205e-07

# %%
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]

epochs = range(len(acc))

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=[20, 5])
ax1.plot(epochs, acc, 'k')
ax1.plot(epochs, val_acc, 'm')
ax1.set_title('Skenario | Accuracy')
ax1.legend(['Train Accuracy','Test accuracy'])

ax2.plot(epochs, loss, 'k')
ax2.plot(epochs, val_loss, 'm')
ax2.set_title('Skenario | Loss')
ax2.legend(['Train Loss','Test Loss'])

# plt.savefig("Test.svg")
plt.show()

# %%
result_train = model.evaluate(train_generator)
print('\n', 'Hasil Akurasi Train = {:.4f}'.format(result_train[1]),
      " Hasil Loss Train = {:.4f}".format(result_train[0]))

result_val = model.evaluate(val_generator)
print('\n', 'Hasil Akurasi Val =  {:.4f}'.format(result_val[1]),
      " Hasil Loss Val = {:.4f}".format(result_val[0]))

# result_test = model.evaluate_generator(test_generator, 733  // 33)
# print('\n', 'Hasil Akurasi Test =  {:.4f}'.format(result_test[1]),
#       " Hasil Loss Test = {:.4f}".format(result_test[0]))
# Out:
# 163/163 [==============================] - 21s 127ms/step - loss: 0.0106 - accuracy: 0.9463
#
#  Hasil Akurasi Train = 0.9463  Hasil Loss Train = 0.0106
# 55/55 [==============================] - 7s 124ms/step - loss: 0.0150 - accuracy: 0.9276
#
#  Hasil Akurasi Val =  0.9276  Hasil Loss Val = 0.0150

# %%
res = model.evaluate(test_generator)
# Out:
# 12/12 [==============================] - 4s 341ms/step - loss: 0.0190 - accuracy: 0.9185

# %%
batch_size = 16  
steps = int(np.ceil(len(data_test) / batch_size))
test_generator.reset()
test_preds = model.predict_generator(test_generator, steps=steps, verbose=1)
test_labels = np.argmax(test_preds, axis=1)
print('Confusion Matrix: \n')
print(confusion_matrix(data_test['diagnosis'].astype(int), test_labels))
# Out:
# C:\Users\Alvin\AppData\Local\Temp\ipykernel_5760\2372437246.py:4: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   test_preds = model.predict_generator(test_generator, steps=steps, verbose=1)
# 12/12 [==============================] - 2s 37ms/step
# Confusion Matrix:
#
# [[83  2  0]
#  [ 3 71  3]
#  [ 1  6 15]]

# %%
print('Classification Report : \n')
target_names = ['0', '1', '2']
print(classification_report(list(data_test['diagnosis'].astype(int)), test_labels, target_names=target_names))

print('Confusion Matrix : \n')
print(confusion_matrix(list(data_test['diagnosis'].astype(int)), test_labels))
# Out:
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97        85
#            1       0.90      0.92      0.91        77
#            2       0.83      0.68      0.75        22
#
#     accuracy                           0.92       184
#    macro avg       0.90      0.86      0.88       184
# weighted avg       0.92      0.92      0.92       184
#
# Confusion Matrix :
#
# [[83  2  0]
#  [ 3 71  3]
#  [ 1  6 15]]

# %%
from sklearn.metrics import  precision_recall_curve, auc, roc_curve
from sklearn.metrics import  accuracy_score, precision_score, recall_score, f1_score

y_pred = data_test['diagnosis'].astype(int)

# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(y_pred, test_labels)
print('Accuracy: %f' % accuracy)

# precision tp / (tp + fp)
precision = precision_score(y_pred, test_labels, average='macro')
print('Precision: %f' % precision)

# recall: tp / (tp + fn)
recall = recall_score(y_pred, test_labels, average='macro')
print('Recall: %f' % recall)

# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_pred, test_labels, average='macro')
print('F1 score: %f' % f1)
# Out:
# Accuracy: 0.918478
# Precision: 0.895363
# Recall: 0.860122
# F1 score: 0.875124

# %%
# precision tp / (tp + fp)
precision = precision_score(y_pred, test_labels, average='weighted')
print('Precision: %f' % precision)

# recall: tp / (tp + fn)
recall = recall_score(y_pred, test_labels, average='weighted')
print('Recall: %f' % recall)

# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_pred, test_labels, average='weighted')
print('F1 score: %f' % f1)
# Out:
# Precision: 0.916456
# Recall: 0.918478
# F1 score: 0.916438

# %%
# precision tp / (tp + fp)
precision = precision_score(y_pred, test_labels, average='micro')
print('Precision: %f' % precision)

# recall: tp / (tp + fn)
recall = recall_score(y_pred, test_labels, average='micro')
print('Recall: %f' % recall)

# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_pred, test_labels, average='micro')
print('F1 score: %f' % f1)
# Out:
# Precision: 0.918478
# Recall: 0.918478
# F1 score: 0.918478

# %%
def plot_conf_matrix(true,pred,classes):
    cf = confusion_matrix(true, pred)
    df_cm = pd.DataFrame(cf, range(len(classes)), range(len(classes)))
    plt.figure(figsize=(8,5.5))
    sns.set(font_scale=1.4)
    sns.heatmap(df_cm, annot=True, annot_kws={"size": 16},xticklabels = classes ,yticklabels = classes,fmt='g',cmap="YlGnBu")
    plt.show()

# %%
labels = ['0 - No DR', '1 - Non Proliferative', '2 - Proliferative']
plot_conf_matrix(list(data_test['diagnosis'].astype(int)),test_labels,labels)

# %%
# model.save('Model_EffnetB0_3class.h5')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 model.save('Model_EffnetB0_3class.h5')
#
# File c:\Users\Alvin\miniconda3\envs\test1\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\Users\Alvin\miniconda3\envs\test1\lib\json\__init__.py:238, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     232 if cls is None:
#     233     cls = JSONEncoder
#     234 return cls(
#     235     skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     236     check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237     separators=separators, default=default, sort_keys=sort_keys,
# --> 238     **kw).encode(obj)
#
# File c:\Users\Alvin\miniconda3\envs\test1\lib\json\encoder.py:199, in JSONEncoder.encode(self, o)
#     195         return encode_basestring(o)
#     196 # This doesn't pass the iterator directly to ''.join() because the
#     197 # exceptions aren't as detailed.  The list call should be roughly
#     198 # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199 chunks = self.iterencode(o, _one_shot=True)
#     200 if not isinstance(chunks, (list, tuple)):
#     201     chunks = list(chunks)
#
# File c:\Users\Alvin\miniconda3\envs\test1\lib\json\encoder.py:257, in JSONEncoder.iterencode(self, o, _one_shot)
#     252 else:
#     253     _iterencode = _make_iterencode(
#     254         markers, self.default, _encoder, self.indent, floatstr,
#     255         self.key_separator, self.item_separator, self.sort_keys,
#     256         self.skipkeys, _one_shot)
# --> 257 return _iterencode(o, 0)
#
# TypeError: Unable to serialize [2.0896919 2.1128857 2.1081853] to JSON. Unrecognized type <class 'tensorflow.python.framework.ops.EagerTensor'>.

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
open('Model_effnetb0_3class.tflite', 'wb').write(tflite_model)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 81). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\Alvin\AppData\Local\Temp\tmptfb1i00q\assets
# INFO:tensorflow:Assets written to: C:\Users\Alvin\AppData\Local\Temp\tmptfb1i00q\assets
# 23392716

# %%
train_dir = os.path.join('DR_Fundus/Training_GB/')
data_test['file_name'] = data_test["id_code"].apply(lambda x: x + ".png")
data_test['file_path'] = data_test['id_code'].map(lambda x: os.path.join(train_dir,'{}.png'.format(x)))

x=0
for i in range(184):
    image = Image.open(data_test.file_path.iloc[i])
    input = np.array(image)
    input = np.expand_dims(input,axis=0)

    predictions = model.predict(input)
    print(np.argmax(predictions))
    if(np.argmax(predictions).astype(str)==data_test.iloc[i]['diagnosis']):
        x=x+1

print(x)
# Out:
# 1/1 [==============================] - 2s 2s/step
# 0
# 1/1 [==============================] - 0s 29ms/step
# 1
# 1/1 [==============================] - 0s 27ms/step
# 0
# 1/1 [==============================] - 0s 27ms/step
# 1
# 1/1 [==============================] - 0s 27ms/step
# 2
# 1/1 [==============================] - 0s 30ms/step
# 0
# 1/1 [==============================] - 0s 26ms/step
# 0
# 1/1 [==============================] - 0s 34ms/step
# 0
# 1/1 [==============================] - 0s 29ms/step
# 0
# 1/1 [==============================] - 0s 35ms/step
# 0
